# %% [markdown]
# <a href="https://colab.research.google.com/github/shahinaNRI-Degree/PythonMiniProject/blob/main/Requests.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
url='https://jsonplaceholder.typicode.com/posts'

# %%
response=requests.get(url=url)

# %%
response.json()
# Out:
# [{'userId': 1,
#   'id': 1,
#   'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit',
#   'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'},
#  {'userId': 1,
#   'id': 2,
#   'title': 'qui est esse',
#   'body': 'est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla'},
#  {'userId': 1,
#   'id': 3,
#   'title': 'ea molestias quasi exercitationem repellat qui ipsa sit aut',
#   'body': 'et iusto sed quo iure\nvoluptatem occaecati omnis eligendi aut ad\nvoluptatem doloribus vel accusantium quis pariatur\nmolestiae porro eius odio et labore et velit aut'},
#  {'userId': 1,
#   'id': 4,
#   'title': 'eum et est occaecati',
# ...

# %%
type(response.json())
# Out:
# list

# %%
for _ in response.json():
  print(f'UserId is {_["userId"]}')
# Out:
# UserId is 1
# UserId is 1
# UserId is 1
# UserId is 1
# UserId is 1
# UserId is 1
# UserId is 1
# UserId is 1
# UserId is 1
# UserId is 1
# UserId is 2
# UserId is 2
# UserId is 2
# UserId is 2
# UserId is 2
# UserId is 2
# UserId is 2
# UserId is 2
# UserId is 2
# UserId is 2
# UserId is 3
# UserId is 3
# UserId is 3
# UserId is 3
# UserId is 3
# UserId is 3
# UserId is 3
# UserId is 3
# UserId is 3
# UserId is 3
# UserId is 4
# UserId is 4
# UserId is 4
# UserId is 4
# UserId is 4
# UserId is 4
# UserId is 4
# UserId is 4
# UserId is 4
# UserId is 4
# UserId is 5
# UserId is 5
# UserId is 5
# UserId is 5
# UserId is 5
# UserId is 5
# UserId is 5
# UserId is 5
# UserId is 5
# UserId is 5
# UserId is 6
# UserId is 6
# UserId is 6
# UserId is 6
# UserId is 6
# UserId is 6
# UserId is 6
# UserId is 6
# UserId is 6
# UserId is 6
# UserId is 7
# UserId is 7
# UserId is 7
# UserId is 7
# UserId is 7
# UserId is 7
# UserId is 7
# UserId is 7
# UserId is 7
# UserId is 7
# UserId is 8
# ...

# %%
for _ in response.json():
  print(f'Post Number is {_["id"]}')
# Out:
# Post Number is 1
# Post Number is 2
# Post Number is 3
# Post Number is 4
# Post Number is 5
# Post Number is 6
# Post Number is 7
# Post Number is 8
# Post Number is 9
# Post Number is 10
# Post Number is 11
# Post Number is 12
# Post Number is 13
# Post Number is 14
# Post Number is 15
# Post Number is 16
# Post Number is 17
# Post Number is 18
# Post Number is 19
# Post Number is 20
# Post Number is 21
# Post Number is 22
# Post Number is 23
# Post Number is 24
# Post Number is 25
# Post Number is 26
# Post Number is 27
# Post Number is 28
# Post Number is 29
# Post Number is 30
# Post Number is 31
# Post Number is 32
# Post Number is 33
# Post Number is 34
# Post Number is 35
# Post Number is 36
# Post Number is 37
# Post Number is 38
# Post Number is 39
# Post Number is 40
# Post Number is 41
# Post Number is 42
# Post Number is 43
# Post Number is 44
# Post Number is 45
# Post Number is 46
# Post Number is 47
# Post Number is 48
# Post Number is 49
# Post Number is 50
# ...

# %%
import requests
url='https://api.github.com/search/repositories'

# %%
parms={
   'q':'requests+languages:python ',
   'sort':'stars',
   'order':'desc'
}

# %%
response=requests.get(url=url,params=parms)

# %%
response.json()
# Out:
# {'total_count': 38,
#  'incomplete_results': False,
#  'items': [{'id': 274472671,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkyNzQ0NzI2NzE=',
#    'name': '.config',
#    'full_name': 'zszszszsz/.config',
#    'private': False,
#    'owner': {'login': 'zszszszsz',
#     'id': 56225718,
#     'node_id': 'MDQ6VXNlcjU2MjI1NzE4',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/56225718?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/zszszszsz',
#     'html_url': 'https://github.com/zszszszsz',
#     'followers_url': 'https://api.github.com/users/zszszszsz/followers',
#     'following_url': 'https://api.github.com/users/zszszszsz/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/zszszszsz/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/zszszszsz/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/zszszszsz/subscriptions',
# ...
