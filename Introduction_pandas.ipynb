# %% [markdown]
# <a href="https://colab.research.google.com/github/shahinaNRI-Degree/PythonMiniProject/blob/main/Introduction_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import random
age=[]
height=[]
weight=[]
speed=[]
for _ in range(100):
  age.append(random.randint(0,100))
  height.append(random.randint(0,100))
  weight.append(random.randint(0,100))
  speed.append(random.randint(0,100))
idata={'Age':age,'Height':height,'Weight':weight,'Speed':speed}

# %%
idata
# Out:
# {'Age': [5,
#   62,
#   7,
#   96,
#   98,
#   7,
#   77,
#   36,
#   70,
#   42,
#   12,
#   15,
#   36,
#   20,
#   10,
#   66,
#   52,
#   22,
#   90,
#   72,
#   24,
#   36,
#   71,
#   31,
#   12,
#   97,
#   75,
#   10,
#   24,
#   34,
#   89,
#   67,
#   75,
#   57,
#   23,
#   42,
#   56,
#   30,
#   52,
#   23,
#   48,
#   45,
#   3,
#   39,
#   92,
#   44,
#   38,
#   90,
#   61,
#   30,
#   32,
#   15,
#   32,
#   55,
#   72,
#   9,
#   40,
#   89,
#   0,
#   73,
#   53,
#   48,
#   94,
#   93,
#   27,
#   28,
#   48,
#   46,
#   44,
#   1,
#   50,
#   3,
#   18,
#   91,
#   13,
#   74,
#   95,
#   72,
#   67,
#   42,
#   51,
#   99,
#   33,
#   73,
#   44,
#   85,
#   2,
#   39,
#   99,
#   13,
#   92,
#   58,
#   9,
#   8,
#   67,
#   69,
#   29,
#   42,
#   33,
#   22],
#  'Height': [49,
#   17,
#   7,
#   93,
#   84,
#   33,
#   91,
#   11,
#   6,
#   6,
#   61,
#   22,
#   77,
#   42,
#   93,
#   10,
#   19,
#   6,
#   82,
#   4,
#   61,
#   5,
#   88,
#   16,
#   82,
#   72,
#   68,
#   7,
#   2,
#   60,
#   23,
#   80,
#   57,
#   49,
#   98,
#   90,
#   99,
#   97,
#   18,
#   28,
#   3,
#   72,
#   90,
#   92,
#   57,
#   85,
#   55,
#   91,
#   56,
#   30,
#   18,
#   74,
#   48,
#   62,
#   70,
#   45,
#   11,
#   62,
#   3,
#   95,
#   69,
#   85,
#   48,
#   3,
#   58,
#   69,
#   90,
#   84,
#   45,
#   57,
#   59,
#   98,
#   97,
#   31,
#   87,
#   71,
#   76,
#   49,
#   23,
#   23,
#   79,
#   2,
#   9,
#   63,
#   50,
#   88,
#   2,
#   3,
#   60,
#   52,
#   92,
#   75,
#   48,
#   78,
#   96,
#   28,
#   40,
#   15,
#   16,
#   69],
#  'Weight': [71,
#   16,
#   23,
#   82,
#   61,
#   35,
#   37,
#   67,
#   12,
#   2,
#   9,
#   30,
#   98,
#   98,
#   28,
#   62,
#   86,
#   100,
#   4,
#   42,
#   8,
#   75,
#   69,
#   33,
#   86,
#   87,
#   70,
#   2,
#   45,
#   77,
#   89,
#   21,
#   57,
#   15,
#   61,
#   47,
#   41,
#   60,
#   65,
#   92,
#   96,
#   46,
#   47,
#   92,
#   13,
#   35,
#   81,
#   51,
#   38,
#   83,
#   77,
#   27,
#   85,
#   100,
#   85,
#   58,
#   47,
#   84,
#   91,
#   95,
#   27,
#   68,
#   23,
#   95,
#   44,
#   71,
#   33,
#   68,
#   1,
#   54,
#   16,
#   4,
#   57,
#   52,
#   20,
#   7,
#   39,
#   10,
#   36,
#   11,
#   71,
#   49,
#   17,
#   14,
#   39,
#   27,
#   0,
#   41,
#   90,
#   95,
#   59,
#   4,
#   45,
#   19,
#   100,
#   18,
#   26,
#   96,
#   7,
#   45],
#  'Speed': [3,
#   98,
#   54,
#   11,
#   76,
#   87,
#   46,
#   78,
#   56,
#   15,
#   55,
#   57,
#   37,
#   93,
#   24,
#   29,
#   62,
#   2,
#   35,
#   57,
#   17,
#   46,
#   61,
#   6,
#   97,
#   66,
#   84,
#   21,
#   4,
#   62,
#   11,
#   46,
#   75,
#   54,
#   24,
#   48,
#   22,
#   85,
#   27,
#   38,
#   19,
#   58,
#   85,
#   74,
#   18,
#   91,
#   84,
#   57,
#   76,
#   10,
#   99,
#   20,
#   19,
#   39,
#   3,
#   87,
#   67,
#   61,
#   88,
#   95,
#   72,
#   60,
#   40,
#   66,
#   27,
#   22,
#   89,
#   21,
#   39,
#   51,
#   19,
#   100,
#   46,
#   73,
#   42,
#   4,
#   91,
#   45,
#   14,
#   72,
#   90,
#   0,
#   25,
#   6,
#   15,
#   62,
#   72,
#   35,
#   46,
#   26,
#   90,
#   73,
#   53,
#   82,
#   28,
#   96,
#   54,
#   90,
#   73,
#   32]}

# %%
df1=pd.DataFrame(idata)

# %%
df1.describe()
# Out:
#               Age      Height      Weight       Speed
# count  100.000000  100.000000  100.000000  100.000000
# mean    47.040000   52.190000   49.920000   50.600000
# std     28.872034   31.737145   30.601934   29.180386
# min      0.000000    2.000000    0.000000    0.000000
# 25%     23.750000   21.250000   23.000000   24.000000
# 50%     44.000000   57.000000   47.000000   53.500000
# 75%     71.250000   80.500000   77.000000   74.250000
# max     99.000000   99.000000  100.000000  100.000000

# %%
df1[['Age','Height']]
# Out:
#     Age  Height
# 0     5      49
# 1    62      17
# 2     7       7
# 3    96      93
# 4    98      84
# ..  ...     ...
# 95   69      28
# 96   29      40
# 97   42      15
# 98   33      16
# 99   22      69
#
# [100 rows x 2 columns]

# %%
df1.loc[0:3,['Age','Height']]
# Out:
#    Age  Height
# 0    5      49
# 1   62      17
# 2    7       7
# 3   96      93

# %%
df2=df1[['Age','Height']]

# %%
df1.sort_index(ascending=False)
# Out:
#     Age  Height  Weight  Speed
# 99   22      69      45     32
# 98   33      16       7     73
# 97   42      15      96     90
# 96   29      40      26     54
# 95   69      28      18     96
# ..  ...     ...     ...    ...
# 4    98      84      61     76
# 3    96      93      82     11
# 2     7       7      23     54
# 1    62      17      16     98
# 0     5      49      71      3
#
# [100 rows x 4 columns]

# %%
df1[0::2].describe()
# Out:
#              Age     Height      Weight      Speed
# count  50.000000  50.000000   50.000000  50.000000
# mean   46.880000  54.400000   48.600000  49.060000
# std    29.668674  31.403886   29.687488  28.813553
# min     0.000000   2.000000    0.000000   3.000000
# 25%    24.000000  23.000000   23.750000  24.000000
# 50%    46.000000  57.500000   45.000000  46.000000
# 75%    70.750000  82.000000   71.000000  74.500000
# max    99.000000  99.000000  100.000000  99.000000

# %%
df1[0::2]
# Out:
#     Age  Height  Weight  Speed
# 0     5      49      71      3
# 2     7       7      23     54
# 4    98      84      61     76
# 6    77      91      37     46
# 8    70       6      12     56
# 10   12      61       9     55
# 12   36      77      98     37
# 14   10      93      28     24
# 16   52      19      86     62
# 18   90      82       4     35
# 20   24      61       8     17
# 22   71      88      69     61
# 24   12      82      86     97
# 26   75      68      70     84
# 28   24       2      45      4
# 30   89      23      89     11
# 32   75      57      57     75
# 34   23      98      61     24
# 36   56      99      41     22
# 38   52      18      65     27
# 40   48       3      96     19
# 42    3      90      47     85
# 44   92      57      13     18
# 46   38      55      81     84
# 48   61      56      38     76
# 50   32      18      77     99
# 52   32      48      85     19
# 54   72      70      85      3
# 56   40      11      47     67
# 58    0       3      91     88
# 60   53      69      27     72
# 62   94      48      23     40
# 64   27      58      44     27
# 66   48      90      33     89
# 68   44      45       1     39
# 70   50      59      16     19
# 72   18      97      57     46
# 74   13      87      20     42
# 76   95      76      39     91
# 78   67      23      36     14
# 80   51      79      71     90
# 82   33       9      17     25
# 84   44      50      39     15
# 86    2       2       0     72
# 88   99      60      90     46
# 90   92      92      59     90
# 92    9      48      45     53
# 94   67      96     100     28
# 96   29      40      26     54
# 98   33      16       7     73

# %%
filter1=df1['Weight']>50

# %%
df1[filter1]
# Out:
#     Age  Height  Weight  Speed
# 0     5      49      71      3
# 3    96      93      82     11
# 4    98      84      61     76
# 7    36      11      67     78
# 12   36      77      98     37
# 13   20      42      98     93
# 15   66      10      62     29
# 16   52      19      86     62
# 17   22       6     100      2
# 21   36       5      75     46
# 22   71      88      69     61
# 24   12      82      86     97
# 25   97      72      87     66
# 26   75      68      70     84
# 29   34      60      77     62
# 30   89      23      89     11
# 32   75      57      57     75
# 34   23      98      61     24
# 37   30      97      60     85
# 38   52      18      65     27
# 39   23      28      92     38
# 40   48       3      96     19
# 43   39      92      92     74
# 46   38      55      81     84
# 47   90      91      51     57
# 49   30      30      83     10
# 50   32      18      77     99
# 52   32      48      85     19
# 53   55      62     100     39
# 54   72      70      85      3
# 55    9      45      58     87
# 57   89      62      84     61
# 58    0       3      91     88
# 59   73      95      95     95
# 61   48      85      68     60
# 63   93       3      95     66
# 65   28      69      71     22
# 67   46      84      68     21
# 69    1      57      54     51
# 72   18      97      57     46
# 73   91      31      52     73
# 80   51      79      71     90
# 88   99      60      90     46
# 89   13      52      95     26
# 90   92      92      59     90
# 94   67      96     100     28
# 97   42      15      96     90

# %%
df1.loc[filter1]
# Out:
#     Age  Height  Weight  Speed
# 0     5      49      71      3
# 3    96      93      82     11
# 4    98      84      61     76
# 7    36      11      67     78
# 12   36      77      98     37
# 13   20      42      98     93
# 15   66      10      62     29
# 16   52      19      86     62
# 17   22       6     100      2
# 21   36       5      75     46
# 22   71      88      69     61
# 24   12      82      86     97
# 25   97      72      87     66
# 26   75      68      70     84
# 29   34      60      77     62
# 30   89      23      89     11
# 32   75      57      57     75
# 34   23      98      61     24
# 37   30      97      60     85
# 38   52      18      65     27
# 39   23      28      92     38
# 40   48       3      96     19
# 43   39      92      92     74
# 46   38      55      81     84
# 47   90      91      51     57
# 49   30      30      83     10
# 50   32      18      77     99
# 52   32      48      85     19
# 53   55      62     100     39
# 54   72      70      85      3
# 55    9      45      58     87
# 57   89      62      84     61
# 58    0       3      91     88
# 59   73      95      95     95
# 61   48      85      68     60
# 63   93       3      95     66
# 65   28      69      71     22
# 67   46      84      68     21
# 69    1      57      54     51
# 72   18      97      57     46
# 73   91      31      52     73
# 80   51      79      71     90
# 88   99      60      90     46
# 89   13      52      95     26
# 90   92      92      59     90
# 94   67      96     100     28
# 97   42      15      96     90

# %%
filter2=df1['Age']>50

# %%
df1[filter1&filter2]
# Out:
#     Age  Height  Weight  Speed
# 3    96      93      82     11
# 4    98      84      61     76
# 15   66      10      62     29
# 16   52      19      86     62
# 22   71      88      69     61
# 25   97      72      87     66
# 26   75      68      70     84
# 30   89      23      89     11
# 32   75      57      57     75
# 38   52      18      65     27
# 47   90      91      51     57
# 53   55      62     100     39
# 54   72      70      85      3
# 57   89      62      84     61
# 59   73      95      95     95
# 63   93       3      95     66
# 73   91      31      52     73
# 80   51      79      71     90
# 88   99      60      90     46
# 90   92      92      59     90
# 94   67      96     100     28
