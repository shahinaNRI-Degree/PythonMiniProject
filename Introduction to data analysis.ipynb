# %% [markdown]
# <a href="https://colab.research.google.com/github/shahinaNRI-Degree/PythonMiniProject/blob/main/Introduction%20to%20data%20analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
a1=[]
a2=[]
a3=[]
a4=[]
a5=[]

# %%
for _ in range(1000):
  a1.append(random.randint(0,100))
  a2.append(random.randint(50,70))
  a3.append(random.randint(10,20))
  a4.append(random.randint(5,10))
  a5.append(random.randint(20,80))

# %%
df={
   'grade':a1,
   'weight':a2,
   'friends':a3,
   'cousins':a4,
   'projects':a5
}

# %%
import pandas as pd

# %%
df1=pd.DataFrame(df)

# %%
df1
# Out:
#      grade  weight  friends  cousins  projects
# 0       68      69       17        6        68
# 1       69      63       11        8        76
# 2       33      53       15        6        60
# 3       59      61       14        5        57
# 4        8      50       20       10        51
# ..     ...     ...      ...      ...       ...
# 995     28      58       20        7        77
# 996     98      69       10        8        60
# 997     60      62       15       10        34
# 998     64      67       17        6        64
# 999     87      60       14        5        30
#
# [1000 rows x 5 columns]

# %%
df1.describe()
# Out:
#              grade       weight      friends      cousins     projects
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     49.599000    60.044000    14.989000     7.473000    49.098000
# std      29.266033     5.808942     3.202989     1.719368    17.222689
# min       0.000000    50.000000    10.000000     5.000000    20.000000
# 25%      23.000000    55.000000    12.000000     6.000000    34.000000
# 50%      49.500000    60.000000    15.000000     7.000000    49.000000
# 75%      75.000000    65.000000    18.000000     9.000000    64.000000
# max     100.000000    70.000000    20.000000    10.000000    80.000000

# %%
df1['grade'].count()
# Out:
# 1000

# %%
friend15=df1['friends']>15

# %%
df1[friend15]. describe()
# Out:
#             grade      weight     friends     cousins    projects
# count  461.000000  461.000000  461.000000  461.000000  461.000000
# mean    48.609544   59.624729   18.017354    7.438178   49.776573
# std     27.703308    5.843629    1.420243    1.706438   17.161508
# min      0.000000   50.000000   16.000000    5.000000   20.000000
# 25%     24.000000   54.000000   17.000000    6.000000   34.000000
# 50%     49.000000   60.000000   18.000000    7.000000   50.000000
# 75%     70.000000   64.000000   19.000000    9.000000   64.000000
# max    100.000000   70.000000   20.000000   10.000000   80.000000

# %%
df1[friend15]
# Out:
#      grade  weight  friends  cousins  projects
# 0       68      69       17        6        68
# 4        8      50       20       10        51
# 6       24      63       18        7        47
# 7       39      62       16        7        47
# 8        4      54       19        7        63
# ..     ...     ...      ...      ...       ...
# 988     40      64       18        6        42
# 989     84      60       19       10        52
# 992     19      63       16        5        60
# 995     28      58       20        7        77
# 998     64      67       17        6        64
#
# [461 rows x 5 columns]

# %%
grade50=df1['grade']>50

# %%
df1[grade50]
# Out:
#      grade  weight  friends  cousins  projects
# 0       68      69       17        6        68
# 1       69      63       11        8        76
# 3       59      61       14        5        57
# 9       74      63       12       10        59
# 11      72      64       20        5        70
# ..     ...     ...      ...      ...       ...
# 994     96      57       15        5        69
# 996     98      69       10        8        60
# 997     60      62       15       10        34
# 998     64      67       17        6        64
# 999     87      60       14        5        30
#
# [489 rows x 5 columns]

# %%
df1[friend15 & grade50]
# Out:
#      grade  weight  friends  cousins  projects
# 0       68      69       17        6        68
# 11      72      64       20        5        70
# 14      65      50       19        9        22
# 18      66      69       19        7        59
# 23      81      70       20        5        57
# ..     ...     ...      ...      ...       ...
# 981     87      53       19        7        62
# 983     87      53       18        7        33
# 985     95      53       16        9        21
# 989     84      60       19       10        52
# 998     64      67       17        6        64
#
# [216 rows x 5 columns]

# %%
df1[friend15 & grade50]['friends']
# Out:
# 0      17
# 11     20
# 14     19
# 18     19
# 23     20
#        ..
# 981    19
# 983    18
# 985    16
# 989    19
# 998    17
# Name: friends, Length: 216, dtype: int64

# %%
df1[friend15 & grade50]['friends'].value_counts()
# Out:
# friends
# 17    50
# 19    47
# 16    41
# 18    40
# 20    38
# Name: count, dtype: int64

# %%
# %matplotlib inline

# %%
df1[friend15 & grade50].plot()
# Out:
# <Axes: >

# %%
df1[friend15 & grade50].plot(x='grade',y='projects')
# Out:
# <Axes: xlabel='grade'>

# %%
df1[friend15 & grade50].plot(x='grade',y='projects',kind='bar')
# Out:
# <Axes: xlabel='grade'>

# %%
df1[friend15 & grade50].plot(x='grade',y='projects',kind='barh')
# Out:
# <Axes: ylabel='grade'>

# %%
df1[friend15 & grade50].plot(x='grade',y='projects',kind='scatter',title='Sample Graph')
# Out:
# <Axes: title={'center': 'Sample Graph'}, xlabel='grade', ylabel='projects'>

# %%
pip install matplotlib

# %%
from matplotlib import pyplot as plt

# %%
df1[friend15 & grade50].plot(x=['grade','friends'],y=['projects','weight'],kind='scatter',title='Sample Graph')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.legend('Test Data')
plt.show()

# %%
fdf=df1[friend15 & grade50]

# %%
fdf
# Out:
#      grade  weight  friends  cousins  projects
# 0       68      69       17        6        68
# 11      72      64       20        5        70
# 14      65      50       19        9        22
# 18      66      69       19        7        59
# 23      81      70       20        5        57
# ..     ...     ...      ...      ...       ...
# 981     87      53       19        7        62
# 983     87      53       18        7        33
# 985     95      53       16        9        21
# 989     84      60       19       10        52
# 998     64      67       17        6        64
#
# [216 rows x 5 columns]

# %%
df1
# Out:
#      grade  weight  friends  cousins  projects
# 0       68      69       17        6        68
# 1       69      63       11        8        76
# 2       33      53       15        6        60
# 3       59      61       14        5        57
# 4        8      50       20       10        51
# ..     ...     ...      ...      ...       ...
# 995     28      58       20        7        77
# 996     98      69       10        8        60
# 997     60      62       15       10        34
# 998     64      67       17        6        64
# 999     87      60       14        5        30
#
# [1000 rows x 5 columns]

# %%
df1.to_csv('//python-apt.tar.xz.csv')
